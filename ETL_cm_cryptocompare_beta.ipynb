# %%
import pandas as pd
import numpy as np
import requests
import datetime

# %% [markdown]
# ### Extracción de data con la API de `CryptoCompare`

# %% [markdown]
# #### `NOTA:` Verificamos APIs de diferentes proveedores y no se encontró información de historial de `suministro de monedas`, si existe la data pero es necesario una API de pago, en este caso al ser un proyecto independiente y en preproducción optamos por usar `CriptoCompare` el cual una de sus APIs deja extraer esta data en forma de historial pero solo se encuentra disponible Bitcoin y Ethereum.

# %%
# Creamos una lista a diferencia de Coingecko lo hacemos con el símbolo, solo hay data de BTC y ETH 
crypto_list = ['BTC', 'ETH']

# %%
# Función para extraer datos con la API, se incluye sistema para detectar errores
def extract_data_blockchain(crypto):
    try:
        response = requests.get(
            'https://min-api.cryptocompare.com/data/blockchain/histo/day',
            params={"fsym": crypto, "apiKey": "9ea7da5f495d73e9a371c56ae3990d91929bba7001cc0db1294d174bcb75781b", "limit": "2000", "toTs": "1519794000"}, # "toTs": "1519794000" se configuró para extraer el segundo tramo de btc y eth
            headers={"Content-type": "application/json; charset=UTF-8"}
        )
        response.raise_for_status()  # Lanza una excepción si la respuesta no es exitosa (por ejemplo, código de estado HTTP 404)

        data = response.json()
        
        # Imprimir la respuesta completa para verificar su estructura
        print(data)

        if 'Data' in data:
            df = pd.json_normalize(data['Data']['Data'])
            # Convierte el sistema de hora Unix a YYYY-MM-DD
            df["time"] = [datetime.datetime.utcfromtimestamp(x).strftime("%Y-%m-%d") for x in df["time"]]
            return df
        else:
            # En caso de que no haya datos en la respuesta
            print(f"No se encontraron datos para {crypto}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"Error de solicitud: {e}")
        return None

# %%
#creamos un diccionario para almacenar los dataframe
df_blocks = {}
# Bucle para extraer los datos de la lista de criptomonedas creadas anteriormente
for cryptocurrency in crypto_list:
    df = extract_data_blockchain(cryptocurrency)
    if df is not None:
        # Guardamos cada dataframe en el diccionario
        df_blocks[cryptocurrency] = df
    else:
        print(f"No se pudo obtener datos para {cryptocurrency}")
# Out:
# {'Response': 'Success', 'Message': '', 'HasWarning': False, 'Type': 100, 'RateLimit': {}, 'Data': {'Aggregated': False, 'TimeFrom': 1519776000, 'TimeTo': 1692576000, 'Data': [{'id': 1182, 'symbol': 'BTC', 'time': 1519776000, 'zero_balance_addresses_all_time': 354073511, 'unique_addresses_all_time': 378480916, 'new_addresses': 275526, 'active_addresses': 809779, 'transaction_count': 189223, 'transaction_count_all_time': 302072984, 'large_transaction_count': 11966, 'average_transaction_value': 7.30930158085989, 'block_height': 511384, 'hashrate': 23194211.4053753, 'difficulty': 3007383866429.73, 'block_time': 556.889610389611, 'block_size': 1054216, 'current_supply': 16892289.7952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1519862400, 'zero_balance_addresses_all_time': 354486975, 'unique_addresses_all_time': 378828064, 'new_addresses': 347148, 'active_addresses': 824240, 'transaction_count': 233744, 'transaction_count_all_time': 302306728, 'large_transaction_count': 12767, 'average_transaction_value': 5.65845488250924, 'block_height': 511549, 'hashrate': 24705802.4989472, 'difficulty': 3007383866429.73, 'block_time': 522.817073170732, 'block_size': 1068240, 'current_supply': 16894352.2952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1519948800, 'zero_balance_addresses_all_time': 354798298, 'unique_addresses_all_time': 379130998, 'new_addresses': 302934, 'active_addresses': 752596, 'transaction_count': 195073, 'transaction_count_all_time': 302501801, 'large_transaction_count': 13654, 'average_transaction_value': 5.00210830183649, 'block_height': 511705, 'hashrate': 23842745.9770064, 'difficulty': 3007383866429.73, 'block_time': 541.741935483871, 'block_size': 861064, 'current_supply': 16896302.2952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1520035200, 'zero_balance_addresses_all_time': 355364564, 'unique_addresses_all_time': 379400579, 'new_addresses': 269581, 'active_addresses': 935002, 'transaction_count': 177024, 'transaction_count_all_time': 302678825, 'large_transaction_count': 11835, 'average_transaction_value': 4.46111425215417, 'block_height': 511885, 'hashrate': 27195753.1306723, 'difficulty': 3007383866429.73, 'block_time': 474.949720670391, 'block_size': 976833, 'current_supply': 16898552.2952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1520121600, 'zero_balance_addresses_all_time': 355846906, 'unique_addresses_all_time': 379647393, 'new_addresses': 246814, 'active_addresses': 805403, 'transaction_count': 160231, 'transaction_count_all_time': 302839056, 'large_transaction_count': 9452, 'average_transaction_value': 3.89392345818163, 'block_height': 512033, 'hashrate': 22143285.637759, 'difficulty': 3007383866429.73, 'block_time': 583.319727891157, 'block_size': 1002853, 'current_supply': 16900402.2952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1520208000, 'zero_balance_addresses_all_time': 356342959, 'unique_addresses_all_time': 379956180, 'new_addresses': 308787, 'active_addresses': 854266, 'transaction_count': 201438, 'transaction_count_all_time': 303040494, 'large_transaction_count': 12870, 'average_transaction_value': 4.48063598215396, 'block_height': 512182, 'hashrate': 23985561.605726, 'difficulty': 3233581400367.36, 'block_time': 579.02027027027, 'block_size': 1016060, 'current_supply': 16902264.7952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1520294400, 'zero_balance_addresses_all_time': 356825463, 'unique_addresses_all_time': 380256519, 'new_addresses': 300339, 'active_addresses': 845625, 'transaction_count': 206016, 'transaction_count_all_time': 303246510, 'large_transaction_count': 12472, 'average_transaction_value': 4.56026266847046, 'block_height': 512338, 'hashrate': 25532022.4173626, 'difficulty': 3290605988755, 'block_time': 553.541935483871, 'block_size': 1022209, 'current_supply': 16904214.7952987}, {'id': 1182, 'symbol': 'BTC', 'time': 1520380800, 'zero_balance_addresses_all_time': 357376476, 'unique_addresses_all_time': 380563452, 'new_addresses': 306933, 'active_addresses': 928851, 'transaction_count' ...
# {'Response': 'Success', 'Message': '', 'HasWarning': False, 'Type': 100, 'RateLimit': {}, 'Data': {'Aggregated': False, 'TimeFrom': 1519776000, 'TimeTo': 1692576000, 'Data': [{'id': 7605, 'symbol': 'ETH', 'time': 1519776000, 'zero_balance_addresses_all_time': 31771371, 'unique_addresses_all_time': 48509188, 'new_addresses': 100769, 'active_addresses': 373013, 'transaction_count': 697138, 'transaction_count_all_time': 167829813, 'large_transaction_count': 1735, 'average_transaction_value': 2.55313193728485, 'block_height': 5174124, 'hashrate': 208.373791023569, 'difficulty': 3052568265040550, 'block_time': 14.6494827878583, 'block_size': 21593, 'current_supply': 97905406.8744797}, {'id': 7605, 'symbol': 'ETH', 'time': 1519862400, 'zero_balance_addresses_all_time': 31812997, 'unique_addresses_all_time': 48606151, 'new_addresses': 96963, 'active_addresses': 342493, 'transaction_count': 661918, 'transaction_count_all_time': 168491731, 'large_transaction_count': 1664, 'average_transaction_value': 2.83787832153192, 'block_height': 5180003, 'hashrate': 211.130525144048, 'difficulty': 3103058386818550, 'block_time': 14.6973460360667, 'block_size': 20663, 'current_supply': 97925794.0307296}, {'id': 7605, 'symbol': 'ETH', 'time': 1519948800, 'zero_balance_addresses_all_time': 31863032, 'unique_addresses_all_time': 48708844, 'new_addresses': 102693, 'active_addresses': 355810, 'transaction_count': 725289, 'transaction_count_all_time': 169217020, 'large_transaction_count': 1707, 'average_transaction_value': 2.43882546025976, 'block_height': 5185902, 'hashrate': 210.196036544769, 'difficulty': 3077244315275450, 'block_time': 14.6398779247203, 'block_size': 22549, 'current_supply': 97946468.9994797}, {'id': 7605, 'symbol': 'ETH', 'time': 1520035200, 'zero_balance_addresses_all_time': 31899318, 'unique_addresses_all_time': 48795502, 'new_addresses': 86658, 'active_addresses': 309914, 'transaction_count': 655700, 'transaction_count_all_time': 169872720, 'large_transaction_count': 1123, 'average_transaction_value': 1.74870264454981, 'block_height': 5191851, 'hashrate': 219.709774395719, 'difficulty': 3190815355052290, 'block_time': 14.5228648285138, 'block_size': 21172, 'current_supply': 97966904.8119797}, {'id': 7605, 'symbol': 'ETH', 'time': 1520121600, 'zero_balance_addresses_all_time': 31932017, 'unique_addresses_all_time': 48869691, 'new_addresses': 74189, 'active_addresses': 287391, 'transaction_count': 624660, 'transaction_count_all_time': 170497380, 'large_transaction_count': 1162, 'average_transaction_value': 1.90158221113643, 'block_height': 5197732, 'hashrate': 213.81204667885, 'difficulty': 3140164441334260, 'block_time': 14.6865646258503, 'block_size': 20793, 'current_supply': 97987125.0932297}, {'id': 7605, 'symbol': 'ETH', 'time': 1520208000, 'zero_balance_addresses_all_time': 31975145, 'unique_addresses_all_time': 48961219, 'new_addresses': 91528, 'active_addresses': 358286, 'transaction_count': 733498, 'transaction_count_all_time': 171230878, 'large_transaction_count': 1645, 'average_transaction_value': 2.4052182407148, 'block_height': 5203617, 'hashrate': 213.608645893883, 'difficulty': 3135226015752460, 'block_time': 14.6774303195105, 'block_size': 22565, 'current_supply': 98007442.5932297}, {'id': 7605, 'symbol': 'ETH', 'time': 1520294400, 'zero_balance_addresses_all_time': 32018544, 'unique_addresses_all_time': 49057255, 'new_addresses': 96036, 'active_addresses': 364951, 'transaction_count': 695129, 'transaction_count_all_time': 171926007, 'large_transaction_count': 1640, 'average_transaction_value': 3.04082142951883, 'block_height': 5209507, 'hashrate': 212.663251158676, 'difficulty': 3118411001962350, 'block_time': 14.6636101205637, 'block_size': 21622, 'current_supply': 98027888.6244797}, {'id': 7605, 'symbol': 'ETH', 'time': 1520380800, 'zero_balance_addresses_all_time': 32066152, 'unique_addresses_all_time': 49158915, 'new_addresses': 101660, 'active_addresses': 467575, 'transaction_count': 767973, 'transaction_count ...
# {'Response': 'Success', 'Message': '', 'HasWarning': False, 'Type': 100, 'RateLimit': {}, 'Data': {'Aggregated': False, 'TimeFrom': 1519776000, 'TimeTo': 1692576000, 'Data': [{'id': 925144, 'symbol': 'OKB', 'time': 1556236800, 'zero_balance_addresses_all_time': 2, 'unique_addresses_all_time': 18, 'new_addresses': 18, 'active_addresses': 18, 'transaction_count': 21, 'transaction_count_all_time': 21, 'large_transaction_count': 16, 'average_transaction_value': 41904762.0952381, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556323200, 'zero_balance_addresses_all_time': 2, 'unique_addresses_all_time': 18, 'new_addresses': 0, 'active_addresses': 0, 'transaction_count': 0, 'transaction_count_all_time': 0, 'large_transaction_count': 0, 'average_transaction_value': 0, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556409600, 'zero_balance_addresses_all_time': 2, 'unique_addresses_all_time': 18, 'new_addresses': 0, 'active_addresses': 0, 'transaction_count': 0, 'transaction_count_all_time': 0, 'large_transaction_count': 0, 'average_transaction_value': 0, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556496000, 'zero_balance_addresses_all_time': 12, 'unique_addresses_all_time': 40, 'new_addresses': 22, 'active_addresses': 23, 'transaction_count': 31, 'transaction_count_all_time': 52, 'large_transaction_count': 0, 'average_transaction_value': 2872.05083870968, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556582400, 'zero_balance_addresses_all_time': 22, 'unique_addresses_all_time': 52, 'new_addresses': 12, 'active_addresses': 15, 'transaction_count': 23, 'transaction_count_all_time': 75, 'large_transaction_count': 2, 'average_transaction_value': 9177.20356521739, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556668800, 'zero_balance_addresses_all_time': 30, 'unique_addresses_all_time': 64, 'new_addresses': 12, 'active_addresses': 14, 'transaction_count': 20, 'transaction_count_all_time': 95, 'large_transaction_count': 0, 'average_transaction_value': 8574.9557, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556755200, 'zero_balance_addresses_all_time': 43, 'unique_addresses_all_time': 79, 'new_addresses': 15, 'active_addresses': 16, 'transaction_count': 32, 'transaction_count_all_time': 127, 'large_transaction_count': 0, 'average_transaction_value': 7212.9250625, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556841600, 'zero_balance_addresses_all_time': 51, 'unique_addresses_all_time': 90, 'new_addresses': 11, 'active_addresses': 14, 'transaction_count': 24, 'transaction_count_all_time': 151, 'large_transaction_count': 0, 'average_transaction_value': 7526.52491666667, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1556928000, 'zero_balance_addresses_all_time': 55, 'unique_addresses_all_time': 95, 'new_addresses': 5, 'active_addresses': 7, 'transaction_count': 14, 'transaction_count_all_time': 165, 'large_transaction_count': 4, 'average_transaction_value': 59494.5255714286, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1557014400, 'zero_balance_addresses_all_time': 62, 'unique_addresses_all_time': 102, 'new_addresses': 7, 'active_addresses': 9, 'transaction_count': 19, 'transaction_count_all_time': 184, 'large_transaction_count': 0, 'average_transaction_value': 9198.11831578947, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1557100800, 'zero_balance_addresses_all_time': 70, 'unique_addresses_all_time': 117, 'new_addresses': 15, 'active_addresses': 18, 'transaction_count': 27, 'transaction_count_all_time': 211, 'large_transaction_count': 0, 'average_transaction_value': 7616.18047407407, 'current_supply': 300000000}, {'id': 925144, 'symbol': 'OKB', 'time': 1557187200, 'zero_balance_addresses_all_time': 81, 'unique_addresses_all_time': 125, 'new_addresses': 8, 'active_addresses': 16, 'transaction_count' ...

# %%
# Este fragmento hace la misma función que el anterior, la diferencia es que la API tiene una limitación de 2000 
# registros y esta segunda extrae el restante necesario para nivelar nuestra data con la de coingecko
# creamos un diccionario para almacenar los dataframe
df_blocks_2 = {}
for cryptocurrency in crypto_list:
    df_2 = extract_data_blockchain(cryptocurrency)
    if df_2 is not None:
        # Guardamos cada dataframe en el diccionario
        df_blocks_2[cryptocurrency] = df_2
    else:
        print(f"No se pudo obtener datos para {cryptocurrency}")
# Out:
# {'Response': 'Success', 'Message': '', 'HasWarning': False, 'Type': 100, 'RateLimit': {}, 'Data': {'Aggregated': False, 'TimeFrom': 1346976000, 'TimeTo': 1519776000, 'Data': [{'id': 1182, 'symbol': 'BTC', 'time': 1346976000, 'zero_balance_addresses_all_time': 5437955, 'unique_addresses_all_time': 6277056, 'new_addresses': 24191, 'active_addresses': 44106, 'transaction_count': 33483, 'transaction_count_all_time': 6871034, 'large_transaction_count': 576, 'average_transaction_value': 549.885765315252, 'block_height': 197769, 'hashrate': 22.479166031691, 'difficulty': 2694047.95295501, 'block_time': 514.736526946108, 'block_size': 83443, 'current_supply': 9888490.00531868}, {'id': 1182, 'symbol': 'BTC', 'time': 1347062400, 'zero_balance_addresses_all_time': 5455455, 'unique_addresses_all_time': 6296502, 'new_addresses': 19446, 'active_addresses': 33700, 'transaction_count': 31173, 'transaction_count_all_time': 6902207, 'large_transaction_count': 404, 'average_transaction_value': 243.29651373128, 'block_height': 197914, 'hashrate': 19.5832550645704, 'difficulty': 2694047.95295501, 'block_time': 590.854166666667, 'block_size': 92160, 'current_supply': 9895740.00071867}, {'id': 1182, 'symbol': 'BTC', 'time': 1347148800, 'zero_balance_addresses_all_time': 5476419, 'unique_addresses_all_time': 6320478, 'new_addresses': 23976, 'active_addresses': 40194, 'transaction_count': 31464, 'transaction_count_all_time': 6933671, 'large_transaction_count': 22, 'average_transaction_value': 123.933140573555, 'block_height': 198073, 'hashrate': 21.3828856883671, 'difficulty': 2694047.95295501, 'block_time': 541.126582278481, 'block_size': 81183, 'current_supply': 9903689.99611865}, {'id': 1182, 'symbol': 'BTC', 'time': 1347235200, 'zero_balance_addresses_all_time': 5495612, 'unique_addresses_all_time': 6341975, 'new_addresses': 21497, 'active_addresses': 37360, 'transaction_count': 33632, 'transaction_count_all_time': 6967303, 'large_transaction_count': 377, 'average_transaction_value': 561.544648914389, 'block_height': 198223, 'hashrate': 20.0885115868454, 'difficulty': 2694047.95295501, 'block_time': 575.993288590604, 'block_size': 95204, 'current_supply': 9911189.99411183}, {'id': 1182, 'symbol': 'BTC', 'time': 1347321600, 'zero_balance_addresses_all_time': 5519081, 'unique_addresses_all_time': 6368531, 'new_addresses': 26556, 'active_addresses': 45243, 'transaction_count': 38225, 'transaction_count_all_time': 7005528, 'large_transaction_count': 613, 'average_transaction_value': 529.198272768078, 'block_height': 198368, 'hashrate': 19.3526149652002, 'difficulty': 2694047.95295501, 'block_time': 597.895833333333, 'block_size': 111399, 'current_supply': 9918439.99261184}, {'id': 1182, 'symbol': 'BTC', 'time': 1347408000, 'zero_balance_addresses_all_time': 5534093, 'unique_addresses_all_time': 6387485, 'new_addresses': 18954, 'active_addresses': 34218, 'transaction_count': 28096, 'transaction_count_all_time': 7033624, 'large_transaction_count': 293, 'average_transaction_value': 386.08498269797, 'block_height': 198523, 'hashrate': 20.7618969680146, 'difficulty': 2694047.95295501, 'block_time': 557.311688311688, 'block_size': 78132, 'current_supply': 9926189.99061185}, {'id': 1182, 'symbol': 'BTC', 'time': 1347494400, 'zero_balance_addresses_all_time': 5551535, 'unique_addresses_all_time': 6406124, 'new_addresses': 18639, 'active_addresses': 35078, 'transaction_count': 29025, 'transaction_count_all_time': 7062649, 'large_transaction_count': 568, 'average_transaction_value': 777.072866938632, 'block_height': 198653, 'hashrate': 17.4763710250896, 'difficulty': 2694047.95295501, 'block_time': 662.085271317829, 'block_size': 100090, 'current_supply': 9932689.99011184}, {'id': 1182, 'symbol': 'BTC', 'time': 1347580800, 'zero_balance_addresses_all_time': 5571256, 'unique_addresses_all_time': 6427477, 'new_addresses': 21353, 'active_addresses': 38280, 'transaction_count': 36118, 'transaction_count_all_time': 7098767, 'large_transaction_count': 948, 'average_t ...
# {'Response': 'Success', 'Message': '', 'HasWarning': False, 'Type': 100, 'RateLimit': {}, 'Data': {'Aggregated': False, 'TimeFrom': 1346976000, 'TimeTo': 1519776000, 'Data': [{'id': 7605, 'symbol': 'ETH', 'time': 1438905600, 'zero_balance_addresses_all_time': 45, 'unique_addresses_all_time': 10306, 'new_addresses': 10306, 'active_addresses': 1389, 'transaction_count': 2035, 'transaction_count_all_time': 2035, 'large_transaction_count': 3, 'average_transaction_value': 987.052938787205, 'block_height': 50613, 'hashrate': 0.0883419303707689, 'difficulty': 1470838650662.28, 'block_time': 16.6493831919815, 'block_size': 632, 'current_supply': 72279919.56198}, {'id': 7605, 'symbol': 'ETH', 'time': 1438992000, 'zero_balance_addresses_all_time': 110, 'unique_addresses_all_time': 10719, 'new_addresses': 413, 'active_addresses': 1207, 'transaction_count': 2344, 'transaction_count_all_time': 4379, 'large_transaction_count': 6, 'average_transaction_value': 5795.27104794149, 'block_height': 55869, 'hashrate': 0.096483107161633, 'difficulty': 1586123528941.25, 'block_time': 16.4393910561369, 'block_size': 667, 'current_supply': 72307862.99948}, {'id': 7605, 'symbol': 'ETH', 'time': 1439078400, 'zero_balance_addresses_all_time': 144, 'unique_addresses_all_time': 10993, 'new_addresses': 274, 'active_addresses': 1112, 'transaction_count': 1312, 'transaction_count_all_time': 5691, 'large_transaction_count': 1, 'average_transaction_value': 888.990756943266, 'block_height': 60992, 'hashrate': 0.101359674382084, 'difficulty': 1709479787484.64, 'block_time': 16.8654822335026, 'block_size': 618, 'current_supply': 72335041.2807301}, {'id': 7605, 'symbol': 'ETH', 'time': 1439164800, 'zero_balance_addresses_all_time': 462, 'unique_addresses_all_time': 11668, 'new_addresses': 675, 'active_addresses': 1429, 'transaction_count': 2027, 'transaction_count_all_time': 7718, 'large_transaction_count': 4, 'average_transaction_value': 825.080113152251, 'block_height': 66247, 'hashrate': 0.111855484194767, 'difficulty': 1837695763267.62, 'block_time': 16.4291968024362, 'block_size': 631, 'current_supply': 72362858.6244801}, {'id': 7605, 'symbol': 'ETH', 'time': 1439251200, 'zero_balance_addresses_all_time': 1774, 'unique_addresses_all_time': 13565, 'new_addresses': 1897, 'active_addresses': 2696, 'transaction_count': 4955, 'transaction_count_all_time': 12673, 'large_transaction_count': 2, 'average_transaction_value': 300.157758093996, 'block_height': 71527, 'hashrate': 0.124449902409336, 'difficulty': 2036390797503.47, 'block_time': 16.3631369577571, 'block_size': 692, 'current_supply': 72390886.4369799}, {'id': 7605, 'symbol': 'ETH', 'time': 1439337600, 'zero_balance_addresses_all_time': 1804, 'unique_addresses_all_time': 13899, 'new_addresses': 334, 'active_addresses': 1218, 'transaction_count': 2009, 'transaction_count_all_time': 14682, 'large_transaction_count': 0, 'average_transaction_value': 374.481903844284, 'block_height': 76651, 'hashrate': 0.130915032416523, 'difficulty': 2207079742289.72, 'block_time': 16.8588717548311, 'block_size': 653, 'current_supply': 72418257.37448}, {'id': 7605, 'symbol': 'ETH', 'time': 1439424000, 'zero_balance_addresses_all_time': 1864, 'unique_addresses_all_time': 14444, 'new_addresses': 545, 'active_addresses': 1605, 'transaction_count': 2834, 'transaction_count_all_time': 17516, 'large_transaction_count': 3, 'average_transaction_value': 631.361479169282, 'block_height': 81937, 'hashrate': 0.14305663636358, 'difficulty': 2336979708057.89, 'block_time': 16.336045411542, 'block_size': 665, 'current_supply': 72446525.4994801}, {'id': 7605, 'symbol': 'ETH', 'time': 1439510400, 'zero_balance_addresses_all_time': 1902, 'unique_addresses_all_time': 15003, 'new_addresses': 559, 'active_addresses': 1892, 'transaction_count': 3166, 'transaction_count_all_time': 20682, 'large_transaction_count': 8, 'average_transaction_value': 726.29449657461, 'block_height': 87746, 'hashrate': 0.179594595227737, 'difficulty': 2671253150471.51, 'block_ ...

# %%
# Declaramos las variables concatenando las dos extracciones, reune los rangos de fecha totales
df_supply_bitcoin = pd.concat([df_blocks_2["BTC"], df_blocks["BTC"]]).copy()
df_supply_ethereum = pd.concat([df_blocks_2["ETH"], df_blocks["ETH"]]).copy()

# %% [markdown]
# #### Función para realizar limpieza, eliminar columnas poco relevantes

# %%
def clean_data(df_crypto):
    df_crypto = df_crypto.astype({'id': 'string'})
    df_crypto['id'] = df_crypto['id'].str.replace("1182", "bitcoin", case=False, regex=False)
    df_crypto['id'] = df_crypto['id'].str.replace("7605", "ethereum", case=False, regex=False)
    df_crypto = df_crypto.drop(columns=['zero_balance_addresses_all_time', 'unique_addresses_all_time',	'new_addresses', 'active_addresses', 'transaction_count', 'transaction_count_all_time', 'large_transaction_count', 'average_transaction_value',	'block_height',	'hashrate',	'difficulty', 'block_time', 'block_size'])
    df_crypto = df_crypto.dropna(subset=['current_supply'])
    df_crypto = df_crypto.astype({'current_supply': 'int64'})
    df_crypto = df_crypto.drop(columns=['symbol'])
    df_crypto.rename(columns={'id': 'cryptocurrency_id'}, inplace=True)
    df_crypto = df_crypto.astype({'time': 'datetime64[ns]'})
    df_crypto = df_crypto.rename(columns={'time': 'timestamp'})
    return df_crypto

# %%
# Activamos la función y guardamos sobre la misma varible
df_supply_bitcoin = clean_data(df_supply_bitcoin)

# %%
# Guardamos en un dataset
df_supply_bitcoin.to_csv("data/beta/bitcoin_current_supply.csv", index=False)

# %%
# Activamos la función y guardamos sobre la misma varible
df_supply_ethereum = clean_data(df_supply_ethereum)

# %%
# Guardamos en un dataset
df_supply_ethereum.to_csv("data/beta/ethereum_current_supply.csv", index=False)
